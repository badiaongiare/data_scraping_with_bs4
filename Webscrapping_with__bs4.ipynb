# %% [markdown]
# ### Webscrapping a car listing site with BeautifulSoup and Requests

# %%
# import required libraries

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### Http Request

# %%
# Store the web url in a variable

website = 'https://www.kaiandkaro.com/vehicles?availability=available&availability=sell_on_behalf&model__make__vehicle_type=Automobile'

# %%
# Get request

response = requests.get(website)

# %%
# Check status

response.status_code
# Out:
# 200

# %% [markdown]
# #### Create soup object

# %%
# creating soup object

soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><meta content="Kai and Karo imports available cars" property="og:title"/><meta content="Kai and Karo car imports. Available vehicles for sale on our portfolio" property="og:description"/><title>Kai &amp; Karo | Car Dealership Kenya | New &amp; Used Cars for Sale</title><meta content="Your Trusted Car Dealership in Nairobi Kenya. We offer an extensive inventory of new and used cars from Top Car Brands. Visit us Today!" name="description"/><meta content="6" name="next-head-count"/><link href="/logo.ico" rel="shortcut icon" type="image/x-icon"/><link href="/logo.ico" rel="shortcut icon"/><meta content="Kai &amp; Karo Car Market place" property="og:site_name"/><meta content="Kai &amp; Karo | Car Dealership Kenya | New &amp; Used Cars for Sale." property="og:title"/><meta content="webapp" property="og:type"/><meta content="Kai and Karo is your one stop Market Place for Brand new &amp; used cars, spare parts and vehicle accessories" property="og:description"/><meta content="Kai &amp; Karo Car Market Place" property="og:site_name"/><meta content="Kai &amp; Karo Car Market Place" property="twitter:title"/><meta content="summary" property="twitter:card"/><meta content="webapp" property="og:type"/><meta content="@kai_and_karo" name="twitter:site"/><meta content="@kai_and_karo" name="twitter:creator"/><meta content="Kai and Karo is your one stop Market Place for Brand new &amp; used cars, spare parts and vehicle accessories" property="twitter:description"/><meta content="DW8m_Vk2N_rwknCfilE_NHgP3chBb8uau_5emz2yZko" name="google-site-verification"/><script>
#               window.__lc = window.__lc || {};
#               window.__lc.license = 16477683;
#               ;(function(n,t,c){function i(n){return e._h?e._h.apply(null,n):e._q.push(n)}var e={_q:[],_h:null,_v:"2.0",on:function(){i(["on",c.call(arguments)])},once:function(){i(["once",c.call(arguments)])},off:function(){i(["off",c.call(arguments)])},get:function(){if(!e._h)throw new Error("[LiveChatWidget] You can't use getters before load.");return i(["get",c.call(arguments)])},call:function(){i(["call",c.call(arguments)])},init:function(){var n=t.createElement("script");n.async=!0,n.type="text/javascript",n.src="https://cdn.livechatinc.com/tracking.js",t.head.appendChild(n)}};!n.__lc.asyncInit&&e.init(),n.LiveChatWidget=n.LiveChatWidget||e}(window,document,[].slice))
#             </script><script>
#               window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#               gtag('config', 'AW-11256104058');
#             </script><script>
#          (function(c,l,a,r,i,t,y){
#              c[a] = c[a] || function () { (c[a].q = c[a].q ||
#              []).push(arguments) };
#              t=l.createElement(r);
#              t.async=1;
#              t.src="https://www.clarity.ms/tag/"+i;
#              y=l.getElementsByTagName(r)[0];
#              y.parentNode.insertBefore(t,y);
#          })(window, document, "clarity", "script", "kjavoqling");</script><noscript><a href="https://www.livechat.com/chat-with/16477683/" rel="nofollow">Chat with us</a>, powered by<!-- --> <a href="https://www.livechat.com/?welcome" rel="noopener nofollow noreferrer" target="_blank">LiveChat</a></noscript><link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/><link as="style" href="/_next/static/css/b8e9f97d17292177.css" rel="preload"/><link data-n-g="" href="/_next/static/css/b8e9f97d17292177.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script defer="" src="/_next/static/chunks/webpack-eb282678f2c9c56d.js"></script><script defer="" src="/_next/static/chunks/framework-5c3dd786a663b156.js"></script><script defer="" src="/_next/static/chunks/main-f26231d200e802b4.js"></script><script defer="" src="/_next/static/chunks/pages/_app-3db499643c0cc1cb.js"></script><script defer="" src="/_next/static/chunks/cb355538-e3a29fe54d1343a3.js"></script><script defer="" src="/_next/static/chunks/2e3a845b-5174516ffe4889a4.js"></script><script defer="" src="/_next/static/chunks/3a17f596-9bd61fe3558f7fe7.js"></script><script defer="" src="/_next/static/chunks/4577d2ec-b3a22f72185a44d7.js"></script><script defer="" src="/_next/static/chunks/fea29d9f-44effa7ac3ad58a2.js"></script><script defer="" src="/_next/static/chunks/828-3a3c6eb4c41de052.js"></script><script defer="" src="/_next/static/chunks/314-a86f9b030df75f8d.js"></script><script defer="" src="/_next/static/chunks/954-ee8244feca6e5fa3.js"></script><script defer="" src="/_next/static/chunks/563-a0831c40552e2179.js"></script><script defer="" src="/_next/static/chunks/600-f2f2c84080aab069.js"></script><script defer="" src="/_next/static/chunks/513-1091134fa47c9b9e.js"></script><script defer="" src="/_next/static/chunks/279-32d27eaa94a6ab6e.js"></script><script defer="" src="/_next/static/chunks/pages/vehicles-3a0022a6c57cfc69.js"></script><script defer="" src="/_next/static/ctDuqPykP-NTMnr5JG-6s/_buildManifest.js"></script><script defer="" src="/_next/static/ctDuqPykP-NTMnr5JG-6s/_ssgManifest.js"></script><style data-href="https://fonts.googleapis.com/css2?family=Caveat:wght@700&amp;display=swap">@font-face{font-family:'Caveat';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/caveat/v18/WnznHAc5bAfYB2QRah7pcpNvOx-pjRV6SIE.woff) format('woff')}@font-face{font-family:'Caveat';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/caveat/v18/WnznHAc5bAfYB2QRah7pcpNvOx-pjRV6eIipZz5Kmgq3s84t.woff) format('woff');unicode-range:U+0460-052F,U+1C80-1C8A,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Caveat';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/caveat/v18/WnznHAc5bAfYB2QRah7pcpNvOx-pjRV6eIGpZz5Kmgq3s84t.woff) format('woff');unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Caveat';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/caveat/v18/WnznHAc5bAfYB2QRah7pcpNvOx-pjRV6eIupZz5Kmgq3s84t.woff) format('woff');unicode-range:U+0100-02BA,U+02BD-02C5,U+02C7-02CC,U+02CE-02D7,U+02DD-02FF,U+0304,U+0308,U+0329,U+1D00-1DBF,U+1E00-1E9F,U+1EF2-1EFF,U+2020,U+20A0-20AB,U+20AD-20C0,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Caveat';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/caveat/v18/WnznHAc5bAfYB2QRah7pcpNvOx-pjRV6eIWpZz5Kmgq3sw.woff) format('woff');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+0304,U+0308,U+0329,U+2000-206F,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}</style></head><body><div id="__next"><style data-emotion="css-global 1ytqnbf">:host,:root,[data-theme]{--chakra-ring-inset:var(--chakra-empty,/*!*/ /*!*/);--chakra-ring-offset-width:0px;--chakra-ring-offset- ...
# It features a 3.0L diesel engine.
# It is ideal for transporting goods in both urban and rural areas. It is a popular choice for business in Logistics,construction and delivery.</p></div></div></a><style data-emotion="css svjswr">.css-svjswr{opacity:0.6;border:0;border-color:inherit;border-style:solid;border-bottom-width:1px;width:100%;}</style><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><style data-emotion="css 167chp9">.css-167chp9{padding:var(--card-padding);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}</style><div class="chakra-card__footer css-167chp9"><style data-emotion="css 1hl87jg">.css-1hl87jg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;}.css-1hl87jg>*:not(style)~*:not(style){margin-top:0.5rem;-webkit-margin-end:0px;margin-inline-end:0px;margin-bottom:0px;-webkit-margin-start:0px;margin-inline-start:0px;}@media screen and (min-width: 48em){.css-1hl87jg{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}.css-1hl87jg>*:not(style)~*:not(style){margin-top:0px;-webkit-margin-end:0px;margin-inline-end:0px;margin-bottom:0px;-webkit-margin-start:0.5rem;margin-inline-start:0.5rem;}}</style><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,149,999</p></span><style data-emotion="css 84zodg">.css-84zodg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}.css-84zodg>*:not(style)~*:not(style){margin-top:0px;-webkit-margin-end:0px;margin-inline-end:0px;margin-bottom:0px;-webkit-margin-start:0.5rem;margin-inline-start:0.5rem;}</style><div class="chakra-stack css-84zodg"><style data-emotion="css yt451y">.css-yt451y{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;white-space:nowrap;vertical-align:middle;-webkit-padding-start:var(--chakra-space-4);padding-inline-start:var(--chakra-space-4);-webkit-padding-end:var(--chakra-space-4);padding-inline-end:var(--chakra-space-4);text-transform:uppercase;font-size:var(--chakra-fontSizes-xs);border-radius:var(--chakra-radii-sm);font-weight:var(--chakra-fontWeights-bold);--badge-bg:var(--chakra-colors-gray-100);--badge-color:var(--chakra-colors-gray-800);background:var(--badge-bg);color:var(--chakra-colors-white);background-color:var(--chakra-colors-black);padding-top:var(--chakra-space-3);padding-bottom:var(--chakra-space-3);-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}@media screen and (min-width: 48em){.css-yt451y{font-size:var(--chakra-fontSizes-3xs);}}.chakra-ui-dark .css-yt451y:not([data-theme]),[data-theme=dark] .css-yt451y:not([data-theme]),.css-yt451y[data-theme=dark]{--badge-bg:rgba(226, 232, 240, 0.16);--badge-color:var(--chakra-colors-gray-200);}.css-yt451y:hover,.css-yt451y[data-hover]{background-color:var(--chakra-colors-gray-700);}</style><span class="chakra-badge css-yt451y">Sell on behalf</span><style data-emotion="css 10dq0y6">.css-10dq0y6{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;position:relative;white ...
# The Mitsubishi RVR can comfortable carry five passengers. Its fuel efficient and also has low maintenance costs.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,399,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/bmw-320i-huxg5oq"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2008</span><h2 class="chakra-heading css-18j379d"> <!-- -->BMW 320i</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2000<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">With a well crafted interior with wood trimmings and finishings, the BMW 320i complements its well designed body style in this metallic black and chrome finishied exterior.
# The BMW 320i is well known for its engaging driving dynamics well suited for car enthusiasts and BMW car lovers alike.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 799,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/subaru-forester-q7anpks"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2016</span><h2 class="chakra-heading css-18j379d"> <!-- -->Subaru Forester</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2000<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The SJ5 is a versatile and rugged SUV suitable for both urban and offroad adventures.
# It has a sleek exterior with sharp lines and a distinctive grille.
# It comes equipped with a 2.0L Boxer engine and as standard, it features Subaru's signature Symmetrical AWD.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 2,699,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/suzuki-baleno-apg1slq"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2019</span><h2 class="chakra-heading css-18j379d"> <!-- -->Suzuki Baleno</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">1400<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Suzuki Baleno is a compact hatchback known for its practicality, efficient fuel economy and affordable pricing.
# It offers a spacious interior,smooth ride and a range of tech features making it a perfect choice for budget conscious buyers looking for a reliable daily driver.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,449,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/nissan-note-fpdxwli"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2015</span><h2 class="chakra-heading css-18j379d"> <!-- -->Nissan Note</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">1200<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Nissan note is a compact and stylish hatchback that offers exceptional fuel efficiency, a spacious interior and advanced safety features. With smart storage options and a sleek design, it's perfect for cuty driving and weekend getaways.
# Discover practicality abd confort in one vehicle.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 829,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/nissan-march-qypm5eg"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2017</span><h2 class="chakra-heading css-18j379d"> <!-- -->Nissan March</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">1200<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Nissan March is known for its practicality and efficient design.
# It features a 1.2L engine, offering excellent fuel economy and maneuverability, making it ideal for city driving.
# With a stylish exterior and comfortable interior which makes it a popular choice for urban commuters.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 829,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/toyota-landcruiser-200-series-46l-v8-zfn0zbk"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2011</span><h2 class="chakra-heading css-18j379d"> <!-- -->Toyota Landcruiser 200 series (4.6L V8)</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">4600<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Toyota Landcruiser 200 series is arguably one of the most versatile all round series.
# It is very stable and quite aggressive with its 4.6L V8 engine. It is by many including businessmen and politicians who are seeking comfort and convenience.
# This specific unit comes with a top of the range aftermarket sound system.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 5,499,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/subaru-levorg-skmlofp"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2014</span><h2 class="chakra-heading css-18j379d"> <!-- -->Subaru Levorg</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2000<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">Equipped with Subaru's renowned safety features and advanced driver assistance systems, the Subaru Levorg ensures a secure driving experience.
# It caters to those seeking a sporty,yet functional vehicle that doesn't compromise on comfort or safety.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,667,499</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/volkswagen-golf-variant-14-mbg2dyp"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2016</span><h2 class="chakra-heading css-18j379d"> <!-- -->Volkswagen Golf Variant 1.4</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">1400<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The 2016 VW golf variant 1.4 is a compact station wagon offering a practical blend of space, performance and efficiency.
# Powered by a 1.4L turbocharged engine,it provides a smooth drive with good fuel economy,ample cargo space and a comfortable interior,making it a versatile family car.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,749,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/mitsubishi-galant-j9jrvpi"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">1998</span><h2 class="chakra-heading css-18j379d"> <!-- -->Mitsubishi Galant</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2000<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Mitsubishi Galant is a classic sedan that combines Mitsubishi's engineering expertise with a timeless design,offering a smooth,confortable and reliable driving experience.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 489,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/peugeot-308-gt-line-ktzrcrf"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2017</span><h2 class="chakra-heading css-18j379d"> <!-- -->Peugeot 308 GT Line</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2000<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Foreign Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Peugeot 308 came as a replacement to the 307. ait in between the 508 and the 208.
# It is powered by a 1200CC turbochaged petrol engine with 128HP and 230NM of torque.
# The speedometre maxs out at 250KM/H, has cruise control,steering controls,climate controls,android infotainment system and electric parking brake.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 2,149,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/mercedes-benz-e200-bxjiatq"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2016</span><h2 class="chakra-heading css-18j379d"> <!-- -->Mercedes Benz E200</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2000<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The 2016 Mercedes Benz E200 is a luxury sedan that combines performance, comfort and advanced technology.
# Powered by a 2.0L turbocharged engine,it offers smooth driving dynamics,a refined interior and a host of safety features making it ideal for both city and highway driving.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 4,599,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/mercedes-benz-c200-rifscbc"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2016</span><h2 class="chakra-heading css-18j379d"> <!-- -->Mercedes Benz C200</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2000<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Mercedes Benz C200 has been the best selling luxury saloon car in Kenya due to many reasons which include; affordable running costs,excellent reliability and good resale values.
# We highly recommend getting this unit.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 3,499,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/lexus-lx-570-thljxbr"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2017</span><h2 class="chakra-heading css-18j379d"> <!-- -->Lexus LX 570</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">5700<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The 2017 Lexus LX570 is a luxury full-size SUV offering a refined blend of off-road capability and on-road comfort.
# It features a 5.7L V8 engine,advanced technology,a plush interior and robust towing capacity,making it ideal for both adventure and luxury.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 11,999,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/toyota-ractis-vmwgwar"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2009</span><h2 class="chakra-heading css-18j379d"> <!-- -->Toyota Ractis</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">1500<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Toyota Ractis has a high roof that can comfortably sit any person of any height.
# The rear seats can fold down to increase cargo space and with its tall and boxy design, it can accomodate large sized cargo.
# It has side mirror indicators, fabric seats, clinate controls, android infotainmeng system amongst other features.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 549,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/subaru-forester-sg5-b4fdivd"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2005</span><h2 class="chakra-heading css-18j379d"> <!-- -->Subaru Forester SG5</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2500<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The 'SG'series refers to the second generation of the Forester produced from 2002 to 2008 while the '5' is the specific model code for the 2.5L turbocharged variants often associated with the XT trim.
# It comes standard with Subaru's Signature Symetrical All Wheel Drive.
# Inside, the Forester XT offers a large confortable cabin with ample space for passengers and cargo which makes the Forester suitable for daily commutes and adventurous trips.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 699,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/toyota-crown-athlete-d1wayxa"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2011</span><h2 class="chakra-heading css-18j379d"> <!-- -->Toyota Crown Athlete</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2490<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">It has a 2.5L V6 engine mated to a 6 speed auto transmission. The Crown Athlete is distinctively sporty with its agressive front grill, sleek body lines and larger multi spoke wheels.
# It features a rear wheel drive (RWD)for a more engaging deiving experience.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,079,998</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/mazda-mpv-fdxu4qp"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2002</span><h2 class="chakra-heading css-18j379d"> <!-- -->Mazda MPV</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2490<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Mazda MPV (Multipurpose Passenger Vehicle)is a minivan manufactured by Mazda.
# It has a spacious interior and seats 7 people. Has a very reliable engine
# 2.5L DOHC (Double Overhead Cam)V6 engine. Other variants come with the inline 4 but this specific unit has the V6 engine.
# This is a great choice if you're looking for a family friendly vehicle with decent performance and reasonable fuel efficiency.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 329,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/nissan-skyline-iatuhg2"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><style data-emotion="css xuq7o7">.css-xuq7o7{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;white-space:nowrap;vertical-align:middle;-webkit-padding-start:var(--chakra-space-4);padding-inline-start:var(--chakra-space-4);-webkit-padding-end:var(--chakra-space-4);padding-inline-end:var(--chakra-space-4);text-transform:uppercase;font-size:var(--chakra-fontSizes-xs);border-radius:var(--chakra-radii-sm);font-weight:var(--chakra-fontWeights-bold);--badge-bg:var(--chakra-colors-gray-500);--badge-color:var(--chakra-colors-white);background:var(--chakra-colors-red-300);color:var(--chakra-colors-green-800);position:absolute;z-index:1;top:var(--chakra-space-4);right:var(--chakra-space-4);text-align:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-top:var(--chakra-space-2);padding-bottom:var(--chakra-space-2);}@media screen and (min-width: 48em){.css-xuq7o7{font-size:var(--chakra-fontSizes-3xs);}}.chakra-ui-dark .css-xuq7o7:not([data-theme]),[data-theme=dark] .css-xuq7o7:not([data-theme]),.css-xuq7o7[data-theme=dark]{--badge-bg:rgba(113, 128, 150, 0.6);--badge-color:var(--chakra-colors-whiteAlpha-800);}</style><span class="chakra-badge css-xuq7o7">Sold</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2011</span><h2 class="chakra-heading css-18j379d"> <!-- -->Nissan Skyline</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">3600<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The 2011 Nissan Skyline blends performance and sophistication offering a dynamic driving experience with its sleek design and advanced technology.Equipped with a powerful engine, precise handling and cutting edge features, the Skyline delivers a smooth yet exhilarating ride making it standout in both style and performance.
# Ideal for those seeking a blend of luxury and sport, the 2011 model is a true testament to Nissan's engineering excellence.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,849,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/2024-toyota-landcruiser-prado-all-rounder-j250-d40jynm"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2024</span><h2 class="chakra-heading css-18j379d"> <!-- -->2024 Toyota Landcruiser Prado Adventure Plus (J250).</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">2800<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Brand New<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">This is the Toyota Landcruiser Prado Adventure Plus trim of the Prado J250 series that comes equipped with a 2.8L turbocharged diesel engine paired to a 6 speed automatic transmission and equipped with a full time 4WD system.
# The fuel tank is around 110 litres and comes with 7 seats.
# It has a bigger 12 inch infotainment  screen and parking sensors all round.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 17,999,999</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Vehicle In Showroom</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/volkswagen-touareg-69nqzxz"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2008</span><h2 class="chakra-heading css-18j379d"> <!-- -->Volkswagen Touareg</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">3000<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">The Volkswagen Touareg has some similarities with the Porsche Cayenne. This one comes equipped with a 3000CC Diesel engine. Perfect for long trips and towing as well. Its is also equipped with an AWD system.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,380,000</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</span><button class="chakra-button css-10dq0y6" type="button"><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M9.01 14H2v2h7.01v3L13 15l-3.99-4v3zm5.98-1v-3H22V8h-7.01V5L11 9l3.99 4z"></path></svg> <p class="chakra-text css-1qkyfb9">Compare</p></button></div></div></div></div></div><div class="chakra-linkbox css-1kh7oap"><div class="chakra-card css-1ndte01"><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/toyota-succeed-1kxny8p"><div style="object-fit:cover;position:relative"><div class="chakra-skeleton css-kx9vo4"></div><span class="chakra-badge css-i1hse3">Available</span></div><div class="chakra-card__header vehicle-card-header css-42ad51"><span class="chakra-badge css-1dub5x4">2016</span><h2 class="chakra-heading css-18j379d"> <!-- -->Toyota Succeed</h2></div><div class="chakra-card__body css-1idwstw"><div class="chakra-stack css-rmxdag"><span class="css-evl6jo">Automatic</span><span class="css-evl6jo">1500<!-- --> CC</span><span class="css-evl6jo"><span class="css-b03jaa">Kenyan Used<!-- --> </span></span></div><div class="chakra-stack css-67n8n0"><p class="chakra-text css-1loynb1">This is a great commercial vehicle perfect for doing business in and out of town. It has a 1500CC engine and a 2WD drivetrain.</p></div></div></a><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><div class="chakra-card__footer css-167chp9"><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,070,000</p></span><div class="chakra-stack css-84zodg"><span class="chakra-badge css-yt451y">Sell on behalf</ ...

# %% [markdown]
# ### Results

# %%
# Get results

results = soup.find_all('div', {'class': 'chakra-card css-1ndte01'})

# %%
# Check lenght of results
# Expected lenght is 25

assert len(results) == 25

# %%
# Check results for the first listing

results[0]
# Out:
# <div class="chakra-card css-1ndte01"><style data-emotion="css 1hnz6hu">.css-1hnz6hu{position:static;}.css-1hnz6hu::before{content:'';cursor:inherit;display:block;position:absolute;top:0px;left:0px;z-index:0;width:100%;height:100%;}</style><a class="chakra-linkbox__overlay css-1hnz6hu" href="/vehicles/mitsubishi-canter-st56nza"><div style="object-fit:cover;position:relative"><style data-emotion="css kx9vo4 animation-14pkoxc">.css-kx9vo4{--skeleton-start-color:var(--chakra-colors-gray-100);--skeleton-end-color:var(--chakra-colors-gray-400);background:var(--skeleton-start-color);border-color:var(--skeleton-end-color);opacity:0.7;border-radius:var(--chakra-radii-sm);-webkit-animation:0.8s linear infinite alternate animation-14pkoxc;animation:0.8s linear infinite alternate animation-14pkoxc;box-shadow:var(--chakra-shadows-none);-webkit-background-clip:padding-box;background-clip:padding-box;cursor:default;color:var(--chakra-colors-transparent);pointer-events:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;height:300px;width:100%;}.css-kx9vo4::before,.css-kx9vo4::after,.css-kx9vo4 *{visibility:hidden;}@-webkit-keyframes animation-14pkoxc{from{border-color:var(--skeleton-start-color);background:var(--skeleton-start-color);}to{border-color:var(--skeleton-end-color);background:var(--skeleton-end-color);}}@keyframes animation-14pkoxc{from{border-color:var(--skeleton-start-color);background:var(--skeleton-start-color);}to{border-color:var(--skeleton-end-color);background:var(--skeleton-end-color);}}</style><div class="chakra-skeleton css-kx9vo4"></div><style data-emotion="css i1hse3">.css-i1hse3{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;white-space:nowrap;vertical-align:middle;-webkit-padding-start:var(--chakra-space-4);padding-inline-start:var(--chakra-space-4);-webkit-padding-end:var(--chakra-space-4);padding-inline-end:var(--chakra-space-4);text-transform:uppercase;font-size:var(--chakra-fontSizes-xs);border-radius:var(--chakra-radii-sm);font-weight:var(--chakra-fontWeights-bold);--badge-bg:var(--chakra-colors-gray-500);--badge-color:var(--chakra-colors-white);background:var(--chakra-colors-green-300);color:var(--chakra-colors-green-800);position:absolute;z-index:1;top:var(--chakra-space-4);right:var(--chakra-space-4);text-align:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-top:var(--chakra-space-2);padding-bottom:var(--chakra-space-2);}@media screen and (min-width: 48em){.css-i1hse3{font-size:var(--chakra-fontSizes-3xs);}}.chakra-ui-dark .css-i1hse3:not([data-theme]),[data-theme=dark] .css-i1hse3:not([data-theme]),.css-i1hse3[data-theme=dark]{--badge-bg:rgba(113, 128, 150, 0.6);--badge-color:var(--chakra-colors-whiteAlpha-800);}</style><span class="chakra-badge css-i1hse3">Available</span></div><style data-emotion="css 42ad51">.css-42ad51{padding:var(--card-padding);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}</style><div class="chakra-card__header vehicle-card-header css-42ad51"><style data-emotion="css 1dub5x4">.css-1dub5x4{display:inline-block;white-space:nowrap;vertical-align:middle;-webkit-padding-start:var(--chakra-space-1);padding-inline-start:var(--chakra-space-1);-webkit-padding-end:var(--chakra-space-1);padding-inline-end:var(--chakra-space-1);text-transform:uppercase;font-size:var(--chakra-fontSizes-xs);border-radius:var(--chakra-radii-sm);font-weight:var(--chakra-fontWeights-bold);--badge-bg:var(--chakra-colors-gray-100);--badge-color:var(--chakra-colors-gray-800);background:var(--badge-bg);color:var(--badge-color);margin-right:var(--chakra-space-4);}.chakra-ui-dark .css-1dub5x4:not([data-theme]),[data-theme=dark] .css-1dub5x4:not([data-theme]),.css-1dub5x4[data-theme=dark]{--badge-bg:rgba(226, 232, 240, 0.16);--badge-color:var(--chakra-colors-gray-200);}</style><spa ...
# It features a 3.0L diesel engine.
# It is ideal for transporting goods in both urban and rural areas. It is a popular choice for business in Logistics,construction and delivery.</p></div></div></a><style data-emotion="css svjswr">.css-svjswr{opacity:0.6;border:0;border-color:inherit;border-style:solid;border-bottom-width:1px;width:100%;}</style><hr aria-orientation="horizontal" class="chakra-divider css-svjswr"/><style data-emotion="css 167chp9">.css-167chp9{padding:var(--card-padding);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}</style><div class="chakra-card__footer css-167chp9"><style data-emotion="css 1hl87jg">.css-1hl87jg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;}.css-1hl87jg>*:not(style)~*:not(style){margin-top:0.5rem;-webkit-margin-end:0px;margin-inline-end:0px;margin-bottom:0px;-webkit-margin-start:0px;margin-inline-start:0px;}@media screen and (min-width: 48em){.css-1hl87jg{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}.css-1hl87jg>*:not(style)~*:not(style){margin-top:0px;-webkit-margin-end:0px;margin-inline-end:0px;margin-bottom:0px;-webkit-margin-start:0.5rem;margin-inline-start:0.5rem;}}</style><div class="chakra-stack css-1hl87jg"><span class="chakra-text css-0"><p class="chakra-text css-0">KES 1,149,999</p></span><style data-emotion="css 84zodg">.css-84zodg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}.css-84zodg>*:not(style)~*:not(style){margin-top:0px;-webkit-margin-end:0px;margin-inline-end:0px;margin-bottom:0px;-webkit-margin-start:0.5rem;margin-inline-start:0.5rem;}</style><div class="chakra-stack css-84zodg"><style data-emotion="css yt451y">.css-yt451y{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;white-space:nowrap;vertical-align:middle;-webkit-padding-start:var(--chakra-space-4);padding-inline-start:var(--chakra-space-4);-webkit-padding-end:var(--chakra-space-4);padding-inline-end:var(--chakra-space-4);text-transform:uppercase;font-size:var(--chakra-fontSizes-xs);border-radius:var(--chakra-radii-sm);font-weight:var(--chakra-fontWeights-bold);--badge-bg:var(--chakra-colors-gray-100);--badge-color:var(--chakra-colors-gray-800);background:var(--badge-bg);color:var(--chakra-colors-white);background-color:var(--chakra-colors-black);padding-top:var(--chakra-space-3);padding-bottom:var(--chakra-space-3);-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}@media screen and (min-width: 48em){.css-yt451y{font-size:var(--chakra-fontSizes-3xs);}}.chakra-ui-dark .css-yt451y:not([data-theme]),[data-theme=dark] .css-yt451y:not([data-theme]),.css-yt451y[data-theme=dark]{--badge-bg:rgba(226, 232, 240, 0.16);--badge-color:var(--chakra-colors-gray-200);}.css-yt451y:hover,.css-yt451y[data-hover]{background-color:var(--chakra-colors-gray-700);}</style><span class="chakra-badge css-yt451y">Sell on behalf</span><style data-emotion="css 10dq0y6">.css-10dq0y6{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;position:relative;white ...

# %% [markdown]
# ### Target the required data

# %%
# Required data

# Name
# Transmission
# Engine rating
# Usage
# YOM
# Price

# %%
# Name of first listing

results[0].find('h2').get_text()
# Out:
# ' Mitsubishi Canter'

# %%
# Transmission  of first listing

results[0].find('span',{'class':'css-evl6jo'}).get_text()
# Out:
# 'Automatic'

# %%
# Engine rating of first listing

results[0].find('span',{'class':'css-evl6jo'}).find_next_sibling('span').get_text()
# Out:
# '3000 CC'

# %%
# Usage of first listing

results[0].find('span',{'class':'css-b03jaa'}).get_text()
# Out:
# 'Kenyan Used '

# %%
# Year of manufacture of first listing

results[0].find('span',{'class':'chakra-badge css-1dub5x4'}).get_text()
# Out:
# '2013'

# %%
# Price of first listing

results[0].find('span', {'class':'chakra-text'}).get_text().replace('\xa0', ' ')
# Out:
# 'KES 1,149,999'

# %% [markdown]
# ### Putting everything together using a for loop

# %%
# Create empty list for each data

name = []
transmission = []
engine_rating = []
usage = []
year_of_manufacture = []
price = []

for result in results:

    # Name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('n/a')
    # Transmission
    try:
        transmission.append(result.find('span',{'class':'css-evl6jo'}).get_text())
    except:
        transmission.append('n/a')
    # Engine rating
    try:
        engine_rating.append(result.find('span',{'class':'css-evl6jo'}).find_next_sibling('span').get_text())
    except:
        engine_rating.append('n/a')
    # Usage
    try:
        usage.append(result.find('span',{'class':'css-b03jaa'}).get_text())
    except:
        usage.append('n/a')
    # Year of Manufacture
    try:
      year_of_manufacture.append(result.find('span',{'class':'chakra-badge css-1dub5x4'}).get_text())
    except:
        year_of_manufacture.append('n/a')
    # Price
    try:
        price.append(result.find('span', {'class':'chakra-text'}).get_text().replace('\xa0', ' '))
    except:
        price.append('n/a')

# %% [markdown]
# ### Create a Pandas Dataframe

# %%
car_listings = pd.DataFrame({'Name': name, 'Transmission': transmission, 'Engine Rating': engine_rating,
                             'Usage': usage, 'Year of Manufacture': year_of_manufacture, 'Price': price})

# %%
# View the dataframe

car_listings
# Out:
#                                                  Name Transmission  \
# 0                                   Mitsubishi Canter    Automatic
# 1                                      Mitsubishi RVR    Automatic
# 2                                            BMW 320i    Automatic
# 3                                     Subaru Forester    Automatic
# 4                                       Suzuki Baleno    Automatic
# 5                                         Nissan Note    Automatic
# 6                                        Nissan March    Automatic
# 7             Toyota Landcruiser 200 series (4.6L V8)    Automatic
# 8                                       Subaru Levorg    Automatic
# 9                         Volkswagen Golf Variant 1.4    Automatic
# 10                                  Mitsubishi Galant    Automatic
# 11                                Peugeot 308 GT Line    Automatic
# 12                                 Mercedes Benz E200    Automatic
# 13                                 Mercedes Benz C200    Automatic
# 14                                       Lexus LX 570    Automatic
# 15                                      Toyota Ractis    Automatic
# 16                                Subaru Forester SG5    Automatic
# 17                               Toyota Crown Athlete    Automatic
# 18                                          Mazda MPV    Automatic
# 19                                     Nissan Skyline    Automatic
# 20   2024 Toyota Landcruiser Prado Adventure Plus ...    Automatic
# 21                                 Volkswagen Touareg    Automatic
# 22                                     Toyota Succeed    Automatic
# 23                                        Toyota Noah    Automatic
# 24                                    Toyota Fortuner    Automatic
#
#    Engine Rating          Usage Year of Manufacture           Price
# 0        3000 CC   Kenyan Used                 2013   KES 1,149,999
# 1        1800 CC   Kenyan Used                 2011   KES 1,399,999
# 2        2000 CC   Kenyan Used                 2008     KES 799,999
# 3        2000 CC   Kenyan Used                 2016   KES 2,699,999
# 4        1400 CC   Kenyan Used                 2019   KES 1,449,999
# 5        1200 CC   Kenyan Used                 2015     KES 829,999
# 6        1200 CC   Kenyan Used                 2017     KES 829,999
# 7        4600 CC   Kenyan Used                 2011   KES 5,499,999
# 8        2000 CC   Kenyan Used                 2014   KES 1,667,499
# 9        1400 CC   Kenyan Used                 2016   KES 1,749,999
# 10       2000 CC   Kenyan Used                 1998     KES 489,999
# 11       2000 CC  Foreign Used                 2017   KES 2,149,999
# 12       2000 CC   Kenyan Used                 2016   KES 4,599,999
# 13       2000 CC   Kenyan Used                 2016   KES 3,499,999
# 14       5700 CC   Kenyan Used                 2017  KES 11,999,999
# 15       1500 CC   Kenyan Used                 2009     KES 549,999
# 16       2500 CC   Kenyan Used                 2005     KES 699,999
# 17       2490 CC   Kenyan Used                 2011   KES 1,079,998
# 18       2490 CC   Kenyan Used                 2002     KES 329,999
# 19       3600 CC   Kenyan Used                 2011   KES 1,849,999
# 20       2800 CC     Brand New                 2024  KES 17,999,999
# 21       3000 CC   Kenyan Used                 2008   KES 1,380,000
# 22       1500 CC   Kenyan Used                 2016   KES 1,070,000
# 23       2000 CC   Kenyan Used                 2017   KES 2,350,000
# 24       2400 CC   Kenyan Used                 2023   KES 7,990,000

# %% [markdown]
# ### Store Output in Excel

# %%
# Storing the output in Excel

car_listings.to_excel('car_listings.xlsx', index=False)

# %% [markdown]
# #### Pagination

# %%
# create empty list for each variable
name = []
transmission = []
engine_rating = []
usage = []
year_of_manufacture = []
price = []

# get listings from the first 50 pages
for i in range(1, 51):
  # website in a variable
  website = 'https://www.kaiandkaro.com/vehicles?availability=available&availability=sell_on_behalf&model__make__vehicle_type=Automobile&page='+str(i)

  # send request to website
  response = requests.get(website)

  # create soup object
  soup = BeautifulSoup(response.content, 'html.parser')

  # results
  results = soup.find_all('div', {'class': 'chakra-card css-1ndte01'})

  # loop through results
  for result in results:

    # Name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('n/a')
    # Transmission
    try:
        transmission.append(result.find('span',{'class':'css-evl6jo'}).get_text())
    except:
        transmission.append('n/a')
    # Engine rating
    try:
        engine_rating.append(result.find('span',{'class':'css-evl6jo'}).find_next_sibling('span').get_text())
    except:
        engine_rating.append('n/a')
    # Usage
    try:
        usage.append(result.find('span',{'class':'css-b03jaa'}).get_text())
    except:
        usage.append('n/a')
    # Year of Manufacture
    try:
      year_of_manufacture.append(result.find('span',{'class':'chakra-badge css-1dub5x4'}).get_text())
    except:
        year_of_manufacture.append('n/a')
    # Price
    try:
        price.append(result.find('span', {'class':'chakra-text'}).get_text().replace('\xa0', ' '))
    except:
        price.append('n/a')

# %%
# Create a dataframe for listings
car_listings = pd.DataFrame({'Name': name, 'Transmission': transmission, 'Engine Rating': engine_rating,
                             'Usage': usage, 'Year of Manufacture': year_of_manufacture, 'Price': price})
car_listings
# Out:
#                                           Name Transmission Engine Rating  \
# 0                            Mitsubishi Canter    Automatic       3000 CC
# 1                               Mitsubishi RVR    Automatic       1800 CC
# 2                                     BMW 320i    Automatic       2000 CC
# 3                              Subaru Forester    Automatic       2000 CC
# 4                                Suzuki Baleno    Automatic       1400 CC
# ...                                        ...          ...           ...
# 1245                 Mazda Premacy 2.2L Diesel    Automatic       2200 CC
# 1246   Toyota Landcruiser GXR 4.5L V8 / MANUAL    Automatic       4500 CC
# 1247                      Audi A4 2.0T QUATTRO    Automatic       2000 CC
# 1248                          Audi Q7 3.0L TDI    Automatic       3000 CC
# 1249                           Toyota Rush 4WD    Automatic       1500 CC
#
#              Usage Year of Manufacture          Price
# 0     Kenyan Used                 2013  KES 1,149,999
# 1     Kenyan Used                 2011  KES 1,399,999
# 2     Kenyan Used                 2008    KES 799,999
# 3     Kenyan Used                 2016  KES 2,699,999
# 4     Kenyan Used                 2019  KES 1,449,999
# ...            ...                 ...            ...
# 1245  Kenyan Used                 2012  KES 1,099,999
# 1246  Kenyan Used                 2016  KES 8,199,999
# 1247  Kenyan Used                 2014  KES 2,299,999
# 1248  Kenyan Used                 2007  KES 2,199,999
# 1249  Kenyan Used                 2013  KES 1,199,999
#
# [1250 rows x 6 columns]

# %%
# store output in excel

car_listings.to_excel('car_listings_pagination.xlsx', index=False)
